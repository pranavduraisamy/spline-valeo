# %%
from gravity_looper import gravity_looper
import warnings
warnings.simplefilter('ignore')

# %%
#| label: p1c1

gravity_looper(psit=1,case=1,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:38<00:00, 4726.98it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c2

gravity_looper(psit=1,case=2,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:37<00:00, 4761.91it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c3

gravity_looper(psit=1,case=3,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:38<00:00, 4738.99it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c1

gravity_looper(psit=2,case=1,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:42<00:00, 4608.86it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c2

gravity_looper(psit=2,case=2,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:42<00:00, 4628.21it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c3

gravity_looper(psit=2,case=3,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:49<00:00, 4413.05it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c1

gravity_looper(psit=3,case=1,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:38<00:00, 4725.12it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c2

gravity_looper(psit=3,case=2,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:30<00:00, 4969.03it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c3

gravity_looper(psit=3,case=3,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:21<00:00, 5285.20it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c1

gravity_looper(psit=4,case=1,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:23<00:00, 5234.71it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c2

gravity_looper(psit=4,case=2,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:20<00:00, 5326.20it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c3

gravity_looper(psit=4,case=3,base_radius=2.187,pfix='radius-sens\\radius-90-2187\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:19<00:00, 5370.72it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed
