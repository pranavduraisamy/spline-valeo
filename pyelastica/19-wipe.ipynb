# %%
from wiper_looper import wiper_looper
import warnings
warnings.simplefilter('ignore')

# %%
#| label: w1

wiper_looper(wipe=1)

# %%
#| label: w2

wiper_looper(wipe=2)

# %%
#| label: w3

wiper_looper(wipe=3)

# %%
#| label: w4

wiper_looper(wipe=4)

# %%
#| label: w5

wiper_looper(wipe=5)
