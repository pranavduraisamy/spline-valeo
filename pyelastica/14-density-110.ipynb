# %%
from gravity_looper import gravity_looper
import warnings
warnings.simplefilter('ignore')

# %%
#| label: p1c1

gravity_looper(psit=1,case=1,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:17<00:00, 5439.93it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c2

gravity_looper(psit=1,case=2,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:20<00:00, 5331.64it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c3

gravity_looper(psit=1,case=3,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:16<00:00, 5497.65it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c1

gravity_looper(psit=2,case=1,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:16<00:00, 5502.94it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c2

gravity_looper(psit=2,case=2,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:17<00:00, 5438.18it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c3

gravity_looper(psit=2,case=3,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:18<00:00, 5410.16it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c1

gravity_looper(psit=3,case=1,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:17<00:00, 5470.07it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c2

gravity_looper(psit=3,case=2,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:14<00:00, 5568.10it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c3

gravity_looper(psit=3,case=3,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:14<00:00, 5578.23it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c1

gravity_looper(psit=4,case=1,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:08<00:00, 5821.37it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c2

gravity_looper(psit=4,case=2,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:07<00:00, 5895.06it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c3

gravity_looper(psit=4,case=3,density=1.353e-6,pfix='density-sens\\density-110-1353\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:06<00:00, 5934.02it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed
