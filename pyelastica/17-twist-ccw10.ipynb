# %%
from gravity_looper import gravity_looper
import warnings
warnings.simplefilter('ignore')

# %%
#| label: p1c1

gravity_looper(psit=1,case=1,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:19<00:00, 5372.25it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c2

gravity_looper(psit=1,case=2,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:27<00:00, 5077.08it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c3

gravity_looper(psit=1,case=3,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:32<00:00, 4914.49it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c1

gravity_looper(psit=2,case=1,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:37<00:00, 4751.93it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c2

gravity_looper(psit=2,case=2,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:34<00:00, 4848.52it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c3

gravity_looper(psit=2,case=3,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:33<00:00, 4901.72it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c1

gravity_looper(psit=3,case=1,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:36<00:00, 4791.29it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c2

gravity_looper(psit=3,case=2,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:35<00:00, 4819.78it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c3

gravity_looper(psit=3,case=3,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:40<00:00, 4671.49it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c1

gravity_looper(psit=4,case=1,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:40<00:00, 4664.30it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c2

gravity_looper(psit=4,case=2,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:38<00:00, 4729.36it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c3

gravity_looper(psit=4,case=3,twist=-10,pfix='twist-sens\\twist-ccw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:35<00:00, 4831.48it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed
