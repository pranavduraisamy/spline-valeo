# %%
from gravity_looper import gravity_looper
import warnings
warnings.simplefilter('ignore')

# %%
#| label: p1c1

gravity_looper(psit=1,case=1,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:19<00:00, 5388.57it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c2

gravity_looper(psit=1,case=2,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:23<00:00, 5210.11it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c3

gravity_looper(psit=1,case=3,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:35<00:00, 4828.94it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c1

gravity_looper(psit=2,case=1,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:39<00:00, 4708.27it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c2

gravity_looper(psit=2,case=2,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:37<00:00, 4763.68it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c3

gravity_looper(psit=2,case=3,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:33<00:00, 4870.43it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c1

gravity_looper(psit=3,case=1,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:37<00:00, 4769.05it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c2

gravity_looper(psit=3,case=2,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:36<00:00, 4782.53it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c3

gravity_looper(psit=3,case=3,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:42<00:00, 4626.97it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c1

gravity_looper(psit=4,case=1,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:43<00:00, 4598.96it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c2

gravity_looper(psit=4,case=2,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:40<00:00, 4662.01it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c3

gravity_looper(psit=4,case=3,twist=10,pfix='twist-sens\\twist-cw10\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:39<00:00, 4707.89it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed
