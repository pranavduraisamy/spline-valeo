# %%
from wiper_looper import wiper_looper
import warnings
warnings.simplefilter('ignore')

# %%
#| label: w1

wiper_looper(wipe=1)
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [01:57<00:00, 6377.50it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: w2

wiper_looper(wipe=2)
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:00<00:00, 6201.50it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: w3

wiper_looper(wipe=3)
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:00<00:00, 6236.00it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: w4

wiper_looper(wipe=4)
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [01:58<00:00, 6319.63it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: w5

wiper_looper(wipe=5)
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [01:59<00:00, 6260.54it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed
