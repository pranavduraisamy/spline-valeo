# %%
from gravity_looper import gravity_looper
import warnings
warnings.simplefilter('ignore')

# %%
#| label: p1c1

gravity_looper(psit=1,case=1,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:05<00:00, 5987.78it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c2

gravity_looper(psit=1,case=2,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:14<00:00, 5568.96it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p1c3

gravity_looper(psit=1,case=3,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:15<00:00, 5518.21it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c1

gravity_looper(psit=2,case=1,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:16<00:00, 5477.13it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c2

gravity_looper(psit=2,case=2,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:17<00:00, 5444.11it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p2c3

gravity_looper(psit=2,case=3,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:28<00:00, 5053.58it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c1

gravity_looper(psit=3,case=1,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:37<00:00, 4748.80it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c2

gravity_looper(psit=3,case=2,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:39<00:00, 4699.05it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p3c3

gravity_looper(psit=3,case=3,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:40<00:00, 4683.58it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c1

gravity_looper(psit=4,case=1,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:43<00:00, 4598.12it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c2

gravity_looper(psit=4,case=2,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:45<00:00, 4521.29it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed

# %%
#| label: p4c3

gravity_looper(psit=4,case=3,youngs_modulus=0.0032445,pfix='youngs-sens\\youngs-90-3244\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
# 100%|██████████| 750000/750000 [02:48<00:00, 4444.67it/s]
# Final time of simulation is :  749.9999999857208
# Simulation finished.
# Task completed
