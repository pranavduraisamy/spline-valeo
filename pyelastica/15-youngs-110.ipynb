# %%
from gravity_looper import gravity_looper
import warnings
warnings.simplefilter('ignore')

# %%
#| label: p1c1

gravity_looper(psit=1,case=1,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')
# Out:
# Added dampner to the simulation
# Added FixedBC
# Simulator finalized
# Running simulation...
#  15%|█▌        | 114085/750000 [00:19<01:47, 5935.10it/s]

# %%
#| label: p1c2

gravity_looper(psit=1,case=2,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p1c3

gravity_looper(psit=1,case=3,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p2c1

gravity_looper(psit=2,case=1,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p2c2

gravity_looper(psit=2,case=2,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p2c3

gravity_looper(psit=2,case=3,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p3c1

gravity_looper(psit=3,case=1,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p3c2

gravity_looper(psit=3,case=2,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p3c3

gravity_looper(psit=3,case=3,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p4c1

gravity_looper(psit=4,case=1,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p4c2

gravity_looper(psit=4,case=2,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')

# %%
#| label: p4c3

gravity_looper(psit=4,case=3,youngs_modulus=0.0039655,pfix='youngs-sens\\youngs-110-3965\\')
