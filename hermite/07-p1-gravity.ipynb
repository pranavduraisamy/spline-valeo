# %% [markdown]
# # ***Description***
#
# ### Visulaization of optimized Hermite spline for P1 case studies. Equal Length constraint used.

# %% [markdown]
# ## Case 01

# %%
from EasyFEA import Display,Models,plt,Mesher,ElemType,Simulations
from EasyFEA.Geoms import Circle,Line
import pandas as pd
import utils 
Display.Clear()

# Import
df=pd.read_csv('../data/2810/p1-case1-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/p1-case1-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# <EasyFEA.models._beam.BeamStructure object at 0x000001C175D76660>
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 9.07e-01
# Ux min = -2.76e-01
#
# Uy max = 5.20e-03
# Uy min = -1.22e+00
#
# Uz max = 0.00e+00
# Uz min = -3.03e+00
#
# =================== TicTac ===================
#
# Mesh : 164.480 ms
# Display : 61.136 ms
# Boundary Conditions : 5.234 ms
# Matrix : 217.004 ms
# Solver : 60.295 ms

# %% [markdown]
# ## Case 02

# %%
from EasyFEA import Display,Models,plt,Mesher,ElemType,Simulations
from EasyFEA.Geoms import Circle,Line
import pandas as pd
import utils 
Display.Clear()

# Import
df=pd.read_csv('../data/2810/p1-case2-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/p1-case2-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# <EasyFEA.models._beam.BeamStructure object at 0x000001D889BADF90>
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 3.95e-01
# Ux min = -5.72e-01
#
# Uy max = 8.85e-01
# Uy min = 0.00e+00
#
# Uz max = 0.00e+00
# Uz min = -1.55e+00
#
# =================== TicTac ===================
#
# Mesh : 308.265 ms
# Display : 98.606 ms
# Boundary Conditions : 9.845 ms
# Matrix : 401.495 ms
# Solver : 111.861 ms

# %% [markdown]
# ## Case 03

# %%
from EasyFEA import Display,Models,plt,Mesher,ElemType,Simulations
from EasyFEA.Geoms import Circle,Line
import pandas as pd
import utils 
Display.Clear()

# Import
df=pd.read_csv('../data/2810/p1-case3-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/p1-case3-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# <EasyFEA.models._beam.BeamStructure object at 0x000001D88AE67C50>
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 3.30e+00
# Ux min = -1.04e-02
#
# Uy max = 0.00e+00
# Uy min = -2.38e+00
#
# Uz max = 1.00e-01
# Uz min = -4.62e+00
#
# =================== TicTac ===================
#
# Mesh : 455.493 ms
# Display : 136.776 ms
# Boundary Conditions : 14.468 ms
# Matrix : 600.697 ms
# Solver : 163.359 ms
