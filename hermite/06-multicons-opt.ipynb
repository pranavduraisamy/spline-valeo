# %% [markdown]
# # ***Description***
#
# ### Visulaization of optimized Hermite spline for all case studies. Equal Length constraint used.

# %% [markdown]
# # Position 1

# %% [markdown]
# ## P1 Case 01

# %%
import utils
from scipy.optimize import minimize
import pandas as pd
import numpy as np

df=pd.read_csv('../data/2810/p1-case1.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p1-case1-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 192.16046
# Given target spline length: 192.16046
# Length of the Hermite Spline: 51.44133
# Achieved Length of the Hermite Spline: 192.16046
#
# Maximum Distance Deviation: 70.8621
# Total Distance Deviation: 4733.3372
#
# Computed Magnitude (M0, M1): 278.4786, 400.8725

# %% [markdown]
# ## P1 Case 02

# %%
df=pd.read_csv('../data/2810/p1-case2.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p1-case2-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 183.67097
# Given target spline length: 183.67097
# Length of the Hermite Spline: 30.56224
# Achieved Length of the Hermite Spline: 183.67097
#
# Maximum Distance Deviation: 47.7803
# Total Distance Deviation: 3502.5043
#
# Computed Magnitude (M0, M1): 409.3669, 446.7399

# %% [markdown]
# ## P1 Case 03

# %%
df=pd.read_csv('../data/2810/p1-case3.csv')

prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p1-case3-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 217.60053
# Given target spline length: 217.60053
# Length of the Hermite Spline: 44.46117
# Achieved Length of the Hermite Spline: 217.60053
#
# Maximum Distance Deviation: 97.4758
# Total Distance Deviation: 6300.6618
#
# Computed Magnitude (M0, M1): 510.7358, 284.8391

# %% [markdown]
# # Positon 2

# %% [markdown]
# ## P2 Case 01

# %%
df=pd.read_csv('../data/2810/p2-case1.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p2-case1-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 192.18051
# Given target spline length: 192.18051
# Length of the Hermite Spline: 63.12531
# Achieved Length of the Hermite Spline: 192.18051
#
# Maximum Distance Deviation: 74.9094
# Total Distance Deviation: 4962.8179
#
# Computed Magnitude (M0, M1): 294.0318, 362.7864

# %% [markdown]
# ## P2 Case 02

# %%
df=pd.read_csv('../data/2810/p2-case2.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p2-case2-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 183.66672
# Given target spline length: 183.66672
# Length of the Hermite Spline: 33.05682
# Achieved Length of the Hermite Spline: 183.66672
#
# Maximum Distance Deviation: 55.1535
# Total Distance Deviation: 4027.1422
#
# Computed Magnitude (M0, M1): 345.9393, 412.9758

# %% [markdown]
# ## P2 Case 03

# %%
df=pd.read_csv('../data/2810/p2-case3.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p2-case3-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 217.58790
# Given target spline length: 217.58790
# Length of the Hermite Spline: 54.14167
# Achieved Length of the Hermite Spline: 217.58790
#
# Maximum Distance Deviation: 96.1058
# Total Distance Deviation: 5926.8679
#
# Computed Magnitude (M0, M1): 581.8953, 177.6020

# %% [markdown]
# # Position 3

# %% [markdown]
# ## P3 Case 01

# %%
df=pd.read_csv('../data/2810/p3-case1.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p3-case1-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 192.18447
# Given target spline length: 192.18447
# Length of the Hermite Spline: 72.11077
# Achieved Length of the Hermite Spline: 192.18447
#
# Maximum Distance Deviation: 74.3783
# Total Distance Deviation: 4556.2519
#
# Computed Magnitude (M0, M1): 461.2620, 127.9018

# %% [markdown]
# ## P3 Case 02

# %%
df=pd.read_csv('../data/2810/p3-case2.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p3-case2-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 183.68014
# Given target spline length: 183.68014
# Length of the Hermite Spline: 39.03914
# Achieved Length of the Hermite Spline: 183.68014
#
# Maximum Distance Deviation: 64.2819
# Total Distance Deviation: 4437.9793
#
# Computed Magnitude (M0, M1): 302.9392, 387.8257

# %% [markdown]
# ## P3 Case 03

# %%
df=pd.read_csv('../data/2810/p3-case3.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p3-case3-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 217.56689
# Given target spline length: 217.56689
# Length of the Hermite Spline: 63.33947
# Achieved Length of the Hermite Spline: 217.56689
#
# Maximum Distance Deviation: 93.3442
# Total Distance Deviation: 5694.1119
#
# Computed Magnitude (M0, M1): 592.5363, 177.0838

# %% [markdown]
# # Position 4

# %% [markdown]
# ## P4 Case 01

# %%
df=pd.read_csv('../data/2810/p4-case1.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p4-case1-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 192.24013
# Given target spline length: 192.24013
# Length of the Hermite Spline: 77.23709
# Achieved Length of the Hermite Spline: 192.24013
#
# Maximum Distance Deviation: 74.0830
# Total Distance Deviation: 4249.8958
#
# Computed Magnitude (M0, M1): 504.7158, 50.7425

# %% [markdown]
# ## P4 Case 02

# %%
df=pd.read_csv('../data/2810/p4-case2.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p4-case2-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 184.71879
# Given target spline length: 184.71879
# Length of the Hermite Spline: 45.51395
# Achieved Length of the Hermite Spline: 184.71879
#
# Maximum Distance Deviation: 73.1128
# Total Distance Deviation: 4792.1007
#
# Computed Magnitude (M0, M1): 247.2740, 411.2880

# %% [markdown]
# ## P4 Case 03

# %%
df=pd.read_csv('../data/2810/p4-case3.csv')
prt=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)

tgt=utils.length(prt.values)             # Target spline length

def obj_fn(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    m0=mag[0]
    m1=mag[1]    
    u0_scld=m0*u0
    u1_scld=m1*u1
    spl=utils.hermite(p0,p1,u0_scld,u1_scld,num_points=n_points)
    dist_err=abs(np.sum((spl-prt_pts)**2))
    return dist_err

def len_up(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2-(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_lo(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return 2+(utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

def len_eq(mag,prt_pts,p0,p1,u0,u1,n_points=100):
    return (utils.length(utils.hermite(p0,p1,mag[0]*u0,mag[1]*u1,num_points=n_points))-utils.length(prt_pts))

constraints=[
    {'type':'eq','fun':len_eq,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_up,'args':(prt.values,p0,p1,u0,u1)},
    # {'type':'ineq','fun':len_lo,'args':(prt.values,p0,p1,u0,u1)}
]

sol=minimize(obj_fn,[1,1],args=(prt.values,p0,p1,u0,u1),method='SLSQP',constraints=constraints)
u0_final=sol.x[0]*u0
u1_final=sol.x[1]*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

pd.DataFrame(spl_tgt, columns=['X','Y','Z']).to_csv('../data/2810/opt/p4-case3-opt.csv',index=False)

print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nMaximum Distance Deviation: {max(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'Total Distance Deviation: {sum(np.linalg.norm(spl_tgt-spl,axis=1)):.4f}')
print(f'\nComputed Magnitude (M0, M1): {sol.x[0]:.4f}, {sol.x[1]:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,tgt=spl_tgt,prt=prt.values,cne=6,intr='d',tgt_label='Optimized hermite spline')
# Out:
# Length of the Prototype Spline: 217.55841
# Given target spline length: 217.55841
# Length of the Hermite Spline: 69.80785
# Achieved Length of the Hermite Spline: 217.55841
#
# Maximum Distance Deviation: 89.1657
# Total Distance Deviation: 5504.9766
#
# Computed Magnitude (M0, M1): 593.9647, 232.7022
