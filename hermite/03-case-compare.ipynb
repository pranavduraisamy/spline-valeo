# %% [markdown]
# # ***Description***
#
# ### Applied the BCs from 3 cases and comparing with spline data from CAD software

# %% [markdown]
# ## Case 01

# %%
import utils
from scipy import optimize
import pandas as pd

df=pd.read_csv('../data/case-01-cad.csv')
prt_df=pd.read_csv('../data/case-01-prototype.csv')
cad=df.iloc[10:,2:].reset_index(drop=True)
prto=prt_df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0, p1, u0_init, u1_init,num_points=51)

tgt=float(df.iloc[0,1])                  # Target spline length

prt=utils.rotate(cad,prto)               # Translate & Rotate prototype coords

obj_fn=lambda x: utils.length(utils.hermite(p0,p1,x*u0,x*u1)) - tgt
sol=optimize.root_scalar(obj_fn, bracket=[0, tgt*3], method='brentq')
solx=sol.root

u0_final=solx*u0
u1_final=solx*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=51)

print(f'Length of the CAD Spline: {utils.length(cad.values):.5f}')
print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nComputed Magnitude (X): {solx:.4f}')

print(f'\nShortest Distance (CAD): {utils.length(pd.concat([cad.iloc[:1], cad.iloc[-1:]]).values):.5f}')
print(f'Shortest Distance (Prototype): {utils.length(pd.concat([prt.iloc[:1], prt.iloc[-1:]]).values):.5f}')
utils.plotter(spl,p0,p1,u0_init,u1_init,cad=cad.values,tgt=spl_tgt,prt=prt.values)
# Out:
# Length of the CAD Spline: 196.62270
# Length of the Prototype Spline: 192.24013
# Given target spline length: 259.70000
# Length of the Hermite Spline: 78.62746
# Achieved Length of the Hermite Spline: 259.66703
#
# Computed Magnitude (X): 518.0345
#
# Shortest Distance (CAD): 76.67809
# Shortest Distance (Prototype): 75.77479

# %% [markdown]
# ## Case 02

# %%
df=pd.read_csv('../data/case-02-cad.csv')
prt_df=pd.read_csv('../data/case-02-prototype.csv')
cad=df.iloc[10:,2:].reset_index(drop=True)
prto=prt_df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0, p1, u0_init, u1_init,num_points=51)

tgt=float(df.iloc[0,1])                  # Target spline length

prt=utils.rotate(cad,prto)               # Translate & Rotate prototype coords

obj_fn=lambda x: utils.length(utils.hermite(p0,p1,x*u0,x*u1)) - tgt
sol=optimize.root_scalar(obj_fn, bracket=[0, tgt*3], method='brentq')
solx=sol.root

u0_final=solx*u0
u1_final=solx*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=51)

print(f'Length of the CAD Spline: {utils.length(cad.values):.5f}')
print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nComputed Magnitude (X): {solx:.4f}')

print(f'\nShortest Distance (CAD): {utils.length(pd.concat([cad.iloc[:1], cad.iloc[-1:]]).values):.5f}')
print(f'Shortest Distance (Prototype): {utils.length(pd.concat([prt.iloc[:1], prt.iloc[-1:]]).values):.5f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,cad=cad.values,tgt=spl_tgt,prt=prt.values,pos=1.25)
# Out:
# Length of the CAD Spline: 186.57826
# Length of the Prototype Spline: 183.67858
# Given target spline length: 259.70000
# Length of the Hermite Spline: 50.25180
# Achieved Length of the Hermite Spline: 259.65722
#
# Computed Magnitude (X): 481.2452
#
# Shortest Distance (CAD): 44.35457
# Shortest Distance (Prototype): 43.52165

# %% [markdown]
# ## Case 03

# %%
df=pd.read_csv('../data/case-03-cad.csv')
cad=df.iloc[10:,2:].reset_index(drop=True)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0, p1, u0_init, u1_init,num_points=51)

tgt=float(df.iloc[0,1])                  # Target spline length

obj_fn=lambda x: utils.length(utils.hermite(p0,p1,x*u0,x*u1)) - tgt
sol=optimize.root_scalar(obj_fn, bracket=[0, tgt*3], method='brentq')
solx=sol.root

u0_final=solx*u0
u1_final=solx*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=51)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=51)

print(f'Length of the CAD Spline: {utils.length(cad.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nComputed Magnitude (X): {solx:.4f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,cad=cad.values,tgt=spl_tgt)
# Out:
# Length of the CAD Spline: 218.98298
# Given target spline length: 259.70000
# Length of the Hermite Spline: 47.53599
# Achieved Length of the Hermite Spline: 259.67286
#
# Computed Magnitude (X): 498.1729

# %% [markdown]
# ## Case 03v1

# %%
df=pd.read_csv('../data/case-03v1-cad.csv')
prt_df=pd.read_csv('../data/case-03v1-prototype.csv')
df=df.drop(4)
prto=prt_df.iloc[10:,2:].reset_index(drop=True)

cad=df.iloc[10:,2:].reset_index(drop=True).astype(float)

p0=df.iloc[5,2:].values.astype(float)    # Point0
p1=df.iloc[6,2:].values.astype(float)    # Point1
u0=df.iloc[8,2:].values.astype(float)    # Unit Vector @ Point0
u1=df.iloc[9,2:].values.astype(float)    # Unit Vector @ Point1
m0=df.iloc[2,1]                          # Magnitude for Vector1
m1=df.iloc[3,1]                          # Magnitude for Vector2
u0_init=u0*m0
u1_init=u1*m1
spl=utils.hermite(p0, p1, u0_init, u1_init,num_points=51)

tgt=float(df.iloc[0,1])                  # Target spline length

prt=utils.rotate(cad,prto)               # Translate & Rotate prototype coords

obj_fn=lambda x: utils.length(utils.hermite(p0,p1,x*u0,x*u1)) - tgt
sol=optimize.root_scalar(obj_fn, bracket=[0, tgt*3], method='brentq')
solx=sol.root

u0_final=solx*u0
u1_final=solx*u1
spl=utils.hermite(p0,p1,u0_init,u1_init,num_points=100)
spl_tgt=utils.hermite(p0,p1,u0_final,u1_final,num_points=100)

print(f'Length of the CAD Spline: {utils.length(cad.values):.5f}')
print(f'Length of the Prototype Spline: {utils.length(prt.values):.5f}')
print(f'Given target spline length: {tgt:.5f}')
print(f'Length of the Hermite Spline: {utils.length(spl.astype(float)):.5f}')
print(f'Achieved Length of the Hermite Spline: {utils.length(spl_tgt.astype(float)):.5f}')
print(f'\nComputed Magnitude (X): {solx:.4f}')

print(f'\nShortest Distance (CAD): {utils.length(pd.concat([cad.iloc[:1], cad.iloc[-1:]]).values):.5f}')
print(f'Shortest Distance (Prototype): {utils.length(pd.concat([prt.iloc[:1], prt.iloc[-1:]]).values):.5f}')

utils.plotter(spl,p0,p1,u0_init,u1_init,cad=cad.values,tgt=spl_tgt,prt=prt.values)
# Out:
# Length of the CAD Spline: 218.95943
# Length of the Prototype Spline: 216.69656
# Given target spline length: 282.00000
# Length of the Hermite Spline: 70.12979
# Achieved Length of the Hermite Spline: 282.00000
#
# Computed Magnitude (X): 600.0915
#
# Shortest Distance (CAD): 69.29379
# Shortest Distance (Prototype): 69.39070
