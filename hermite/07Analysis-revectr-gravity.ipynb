# %% [markdown]
# # ***Description***
#
# ### Applying gravity/ self weight load for multicons opt

# %% [markdown]
# # Position 1

# %% [markdown]
# ## P1 Case 01

# %%
from EasyFEA import Display,Models,plt,Mesher,ElemType,Simulations
from EasyFEA.Geoms import Circle,Line
import pandas as pd
import utils 
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p1-case1-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p1-case1-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 6.19e-01
# Ux min = -4.73e-01
#
# Uy max = 4.88e-03
# Uy min = -1.34e+00
#
# Uz max = 0.00e+00
# Uz min = -2.88e+00
#
# =================== TicTac ===================
#
# Mesh : 171.028 ms
# Display : 75.887 ms
# Boundary Conditions : 4.462 ms
# Matrix : 211.251 ms
# Solver : 57.431 ms

# %% [markdown]
# ## P1 Case 02

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p1-case2-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p1-case2-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 1.33e-01
# Ux min = -6.40e-01
#
# Uy max = 9.41e-01
# Uy min = 0.00e+00
#
# Uz max = 0.00e+00
# Uz min = -1.43e+00
#
# =================== TicTac ===================
#
# Mesh : 321.460 ms
# Display : 120.558 ms
# Boundary Conditions : 9.283 ms
# Matrix : 419.544 ms
# Solver : 117.503 ms

# %% [markdown]
# ## P1 Case 03

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p1-case3-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p1-case3-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 5.31e-01
# Ux min = -1.13e-02
#
# Uy max = 2.75e-01
# Uy min = -5.74e-01
#
# Uz max = 4.21e-02
# Uz min = -2.20e+00
#
# =================== TicTac ===================
#
# Mesh : 475.785 ms
# Display : 166.180 ms
# Boundary Conditions : 13.978 ms
# Matrix : 634.912 ms
# Solver : 173.862 ms

# %% [markdown]
# # Position 2

# %% [markdown]
# ## P2 Case 01

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p2-case1-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p2-case1-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 3.33e-01
# Ux min = -1.35e-01
#
# Uy max = 5.83e-02
# Uy min = -7.11e-01
#
# Uz max = 0.00e+00
# Uz min = -2.06e+00
#
# =================== TicTac ===================
#
# Mesh : 630.953 ms
# Display : 204.855 ms
# Boundary Conditions : 18.725 ms
# Matrix : 837.086 ms
# Solver : 228.450 ms

# %% [markdown]
# ## P2 Case 02

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p2-case2-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p2-case2-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 0.00e+00
# Ux min = -6.23e-01
#
# Uy max = 5.76e-01
# Uy min = 0.00e+00
#
# Uz max = 0.00e+00
# Uz min = -1.50e+00
#
# =================== TicTac ===================
#
# Mesh : 789.539 ms
# Display : 249.635 ms
# Boundary Conditions : 23.733 ms
# Matrix : 1.054 s
# Solver : 286.718 ms

# %% [markdown]
# ## P2 Case 03

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p2-case3-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p2-case3-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 0.00e+00
# Ux min = -2.60e+00
#
# Uy max = 1.10e+00
# Uy min = 0.00e+00
#
# Uz max = 0.00e+00
# Uz min = -1.65e+00
#
# =================== TicTac ===================
#
# Mesh : 946.169 ms
# Display : 294.967 ms
# Boundary Conditions : 28.906 ms
# Matrix : 1.273 s
# Solver : 344.873 ms

# %% [markdown]
# # Position 3

# %% [markdown]
# ## P3 Case 01

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p3-case1-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p3-case1-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 1.35e+00
# Ux min = -7.64e-03
#
# Uy max = 1.21e+00
# Uy min = -2.18e-02
#
# Uz max = 0.00e+00
# Uz min = -2.52e+00
#
# =================== TicTac ===================
#
# Mesh : 1.107 s
# Display : 345.042 ms
# Boundary Conditions : 34.356 ms
# Matrix : 1.489 s
# Solver : 404.407 ms

# %% [markdown]
# ## P3 Case 02

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p3-case2-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p3-case2-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 0.00e+00
# Ux min = -6.46e-01
#
# Uy max = 4.20e-02
# Uy min = -7.44e-01
#
# Uz max = 0.00e+00
# Uz min = -1.58e+00
#
# =================== TicTac ===================
#
# Mesh : 1.267 s
# Display : 391.341 ms
# Boundary Conditions : 39.581 ms
# Matrix : 1.708 s
# Solver : 464.877 ms

# %% [markdown]
# ## P3 Case 03

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p3-case3-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p3-case3-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 0.00e+00
# Ux min = -2.76e+00
#
# Uy max = 1.31e+00
# Uy min = 0.00e+00
#
# Uz max = 0.00e+00
# Uz min = -1.91e+00
#
# =================== TicTac ===================
#
# Mesh : 1.424 s
# Display : 437.655 ms
# Boundary Conditions : 44.658 ms
# Matrix : 1.923 s
# Solver : 526.270 ms

# %% [markdown]
# # Position 4

# %% [markdown]
# ## P4 Case 01

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p4-case1-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p4-case1-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 4.16e-01
# Ux min = -2.82e-01
#
# Uy max = 3.49e-01
# Uy min = -1.10e-02
#
# Uz max = 5.10e-02
# Uz min = -1.17e+00
#
# =================== TicTac ===================
#
# Mesh : 1.582 s
# Display : 482.172 ms
# Boundary Conditions : 49.521 ms
# Matrix : 2.133 s
# Solver : 583.700 ms

# %% [markdown]
# ## P4 Case 02

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p4-case2-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p4-case2-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 0.00e+00
# Ux min = -8.11e-01
#
# Uy max = 2.88e-02
# Uy min = -1.20e+00
#
# Uz max = 0.00e+00
# Uz min = -2.16e+00
#
# =================== TicTac ===================
#
# Mesh : 1.731 s
# Display : 525.899 ms
# Boundary Conditions : 54.368 ms
# Matrix : 2.349 s
# Solver : 646.660 ms

# %% [markdown]
# ## P4 Case 03

# %%
Display.Clear()

# Import
df=pd.read_csv('../data/2810/rev-opt/p4-case3-opt.csv')
df=df.values

# CS
circle_ot=Circle((0,0),6,0.2)
circle_in=Circle((0,0),3.5,0.25,isHollow=True)
section=circle_ot.Mesh_2D([circle_in],ElemType.QUAD8)
Display.Plot_Mesh(section)

# Spline
beam=[]
for i in range(len(df)-1):
    p1=df[i]
    p2=df[i+1]
    line=Line(p1,p2)
    el=Models.BeamElasIsot(3,line,section,10,0.49)
    beam.append(el)

mesh=Mesher().Mesh_Beams(beams=beam,elemType=ElemType.SEG2)

spline=Models.BeamStructure(beam)


load=-1*((utils.length(df)*section.area*1.23*9.81*1e-6))

# BC
simu=Simulations.BeamSimu(mesh,spline)
simu.add_dirichlet(mesh.Nodes_Point(df[0]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_dirichlet(mesh.Nodes_Point(df[-1]),[0] * 6,['x','y','z','rx','ry','rz'])
simu.add_lineLoad(mesh.Nodes_Points(df[1:-1]),[load/len(df[1:-1])],['z'])

Display.Plot_BoundaryConditions(simu)

for i  in range(1,len(df)-1):
    simu.add_connection_fixed(mesh.Nodes_Point(df[i]))

# Solve the beam problem and get displacement results
sol=simu.Solve()
simu.Save_Iter()

# Results
Display.Plot_Mesh(simu,1)

pd.DataFrame(simu.Results_displacement_matrix(),columns=['X','Y','Z']).to_csv('../data/2810/rev-grav/p4-case3-grav.csv',index=False)

print(simu)

plt.show()
# Out:
# ==================== Mesh ====================
#
# Element type: SEG2
# Ne = 99, Nn = 198, dof = 198
#
# ==================== Model ====================
#
# ...
#
# solver : cg
#
# ============= Boundary Conditions =============
#
# Unspecified.
#
# =================== Results ===================
#
#
#
# Ux max = 0.00e+00
# Ux min = -2.95e+00
#
# Uy max = 1.64e+00
# Uy min = 0.00e+00
#
# Uz max = 0.00e+00
# Uz min = -1.99e+00
#
# =================== TicTac ===================
#
# Mesh : 1.890 s
# Display : 568.883 ms
# Boundary Conditions : 59.005 ms
# Matrix : 2.567 s
# Solver : 708.349 ms
