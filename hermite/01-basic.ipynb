# %% [markdown]
# # ***Description***
#
# ## *Given,*
#
# ### Boundary points (P0, P1), Unit vectors (U0, U1) and its magnitude
#
# ## *Does,*
#
# - ### Computes and Plot the Hermite Spline
# - ### Computes its length

# %%
import utils
import numpy as np

p0=np.array([7,10,0])   # Point0
p1=np.array([20,3,5])   # Point1
u0=np.array([1,1,2])    # Unit Vector @ Point0
u1=np.array([2,0,1])    # Unit Vector @ Point1
m=1                     # Magnitude
u0=u0*m
u1=u1*m
spl=utils.hermite(p0, p1, u0, u1)

print(f'Length of the curve: {utils.length(spl):.5f}')

utils.plotter(spl,p0,p1,u0,u1)
# Out:
# Length of the curve: 15.64469
